# %% [markdown]
# ## Lab 8:  Clustering
#
# Author: Haylee Oyler
#
# Environmental justice (EJ) seeks to ensure that all communities, regardless of socioeconomic status or demographic background, have equal access to clean air, water, and, in the form of energy justice, access to renewable energy resources while minimizing exposure to environmental hazards. In this lab, we will apply clustering analysis to explore how U.S. counties group together based on renewable energy potential, demographic characteristics, and environmental risk factors.
#
# The EEIP dataset was collated by the National Renewable Energy Lab (NREL) and contains a large set of features from multiple other databases including SLOPE (renewable energy potential) and EJSCREEN (environmental risk indicators).
#
# Link to metadata: https://ucsb.box.com/s/x3olvh3rd8w5h7xz8jnm3v8g3t4ajjsg
#
# First you will step through a guided clustering exploration of renewable energy production potential.  Then you will formulate a question of your own that brings in an environmental justice component.

# %% [markdown]
# ### Step 0: Load Libraries and Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster

# Load the EEIP dataset 
# eeip_data = pd.read_csv("/courses/EDS232/Data/eeip.data.csv")
eeip_data = pd.read_csv("data/eeip-data.csv")

# %% [markdown]
# ## Part I:
# In this part, we will step through an analysis that examines how US counties cluster in their potential production of renewable energy.
#
# ### Step 1: Exploratory Data Analysis
#
# First we need to check for missing data and remove incomplete rows. Since clustering is a distance-based technique, we also need to ensure that the features used for clustering are scaled appropriately to prevent dominant features from skewing results.  For our first analysis, use the following variables from the SLOPE dataset related to energy production potential as your features:
# - `utility_pv_technical_generation_potential_mwh`
# - `residential_pv_technical_generation_potential_mwh`
# - `land_based_wind_technical_generation_potential_mwh`
# - `commercial_pv_technical_generation_potential_mwh`
#
# *Information on these variables is available on line 7 of the ColumnsExplained tab of the metadata*
#
# Once you have removed incomplete rows and scaled, print the shape of your processed dataframe.

# %%
# Assign features
X = eeip_data[['utility_pv_technical_generation_potential_mwh',
                'residential_pv_technical_generation_potential_mwh','land_based_wind_technical_generation_potential_mwh','commercial_pv_technical_generation_potential_mwh']]

# Drop NAs from target features
X = X.dropna()

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# Print shape of standardized data frame
X_scaled.shape
# Out:
# (3107, 4)

# %% [markdown]
# ### Step 2: Hierarchical Clustering Analysis
#
# Now that we have preprocessed our dataset and standardized the energy potential features, we will use hierarchical clustering to explore how counties group together based on their energy potential.
#
# A dendrogram is a tree-like visualization that shows how clusters are merged step by step. By analyzing the dendrogram, we can decide the optimal number of clusters by looking at the distance between merges.
#
# Use `linkage()` to perform the clustering.  Use 'ward' for the `method` parameter, a method which minimizes the variance within clusters, producing well-balanced groups. We will first visualize the **full dendrogram** using `dendrogram` before deciding on a truncation strategy.

# %%
# Perform clustering analysis
cluster_mod = linkage(X_scaled, method='ward')

# Plot dendrogram tree
dendrogram(cluster_mod, no_labels=True, show_leaf_counts=False)
plt.show()

# %% [markdown]
# ### Step 3: Set Up Cluster Interpretation
#
# After determining the optimal number of clusters from the dendrogram, we now assign each county to a cluster using the extracted cluster labels.
#
# To better understand the clustering results, we will:
# - Define `num_clusters` as the ideal number of clusters based on the dendrogram created above
# - Extract cluster assignment attribute from the hierarchical clustering using `fcluster()` with `criterion = "maxclust"`
# - Create a new variable `Cluster` in your cleaned dataframe and assign cluster labels to it
# - Compute and print the mean values of the original energy potential features for each cluster.
#
# This summary will help us interpret how counties differ in energy potential across clusters and inform possible next steps for analysis.

# %%
# Based on the number of colors on the tree
num_clusters = 4 

# Extract cluster assignment
clust_assign = fcluster(cluster_mod, criterion='maxclust', t=num_clusters)

# Append cluster assignment to data frame 
X_scaled['cluster'] = clust_assign

# Find mean value of energy potential features for each cluster
mean_values = X_scaled.groupby('cluster').mean()
mean_values
# Out:
#          utility_pv_technical_generation_potential_mwh  \
# cluster
# 1                                             2.831068
# 2                                            -0.184742
# 3                                            -0.076363
# 4                                            -0.661236
#
#          residential_pv_technical_generation_potential_mwh  \
# cluster
# 1                                                -0.193351
# 2                                                -0.121549
# 3                                                 3.631745
# 4                                                26.888227
#
#          land_based_wind_technical_generation_potential_mwh  \
# cluster
# 1                                                 3.004580
# 2                                                -0.185776
# 3                                                -0.382148
# 4                                                -0.527199
#
#          commercial_pv_technical_generation_potential_mwh
# cluster
# 1                                               -0.197860
# 2                                               -0.104943
# 3                                                3.046819
# 4                                               37.606587

# %% [markdown]
# ### Step 4: Visualizing Energy Potential Across Clusters
# Now that we have assigned cluster labels, we want to understand how energy potential differs across clusters. To do this, we will visualize these differences using a grouped bar chart.
#
# Each bar should represent the mean value of an energy potential indicator for a specific cluster. These different patterns of potential is what caused the model to segregate the clusters in the way that it did.

# %%
# Plot dodged Bar Chart
mean_values.plot(kind="bar", colormap="viridis", figsize=(8, 5))

plt.ylim(-5, 40)
plt.xlabel("Cluster")
plt.ylabel("MWH")
plt.title("Energy potential across clusters")
plt.legend(title="Energy Indicator")

plt.show()

# %%
# plt.figure(figsize=(8, 5))
# sns.barplot(data=mean_values, x="cluster", y="Sales", hue="cluster", palette="viridis")

# %% [markdown]
# ### Step 5: Interpret Clustering Results
# Interpret your plot of the resulting clusters.  How would you characterize and compare the four different clusters in terms of their profile of energy generation?

# %% [markdown]
# Cluster 4 clearly demonstrates the highest solar energy generation, with around 60 MWH of energy being produced by reseidential and commerical solar in that cluster.
#
# Cluster 3 has a small amount of residential and commercial solar, but much less compared to cluster 4. This might be an area with new/blossoming solar development or that doesn't receive a lot of sunlight.
#
# Cluster 2 has very little renewable at all, suggesting it could be a region heavily dependent on fossil fuels.
#
# Cluster 1 has a small amount of utility solar and wind power.

# %% [markdown]
# ## Part II: Environmental Justice Metrics
# Now it's your turn.
#
# So far, we have clustered counties based on **energy potential**, but energy potential alone does not tell the full story of **energy equity and access**. To deepen the analysis, we need to consider environmental justice (EJ) factors that affect communities’ ability to benefit from renewable energy and the environmental burdens they already experience.
#
# 1. Explore EJSCREEN variables:
#    - The EJSCREEN subset of our dataset contains metrics on pollution burden, demographics (population size), and health risks (*lines 31-41 of the ColumnsExplained tab in the metadata sheet linked above*).
#    - Identify 1-3 variables that could be important for energy equity analysis.  You could introduce them either as clustering features, as post-clustering variables to help interpret the clusters, or both.
#
# 2. Modify the clustering approach:
#    - Add your selected EJSCREEN variables to our feature set.
#    - Re-run the hierarchical clustering analysis with the expanded dataset (if you added any as clustering features).
#
# 3. Interpret the Results:
#    Your interpretation could include considerations such as:
#    - How do clusters change when EJSCREEN variables are included?
#    - Are counties with high renewable energy potential also burdened by environmental risks?
#    - What policy recommendations might emerge from these findings?

# %%
#Your Part 2 Code
pd.set_option('display.max_columns', None) 

eeip_data.head()
# Out:
#    county_fips   county state  county_pop  utilitypv_techpot_quint  \
# 0         1001  Autauga    AL       55200                        3
# 1         1003  Baldwin    AL      208107                        5
# 2         1005  Barbour    AL       25782                        4
# 3         1007     Bibb    AL       22527                        2
# 4         1009   Blount    AL       57645                        2
#
#    utility_pv_technical_generation_potential_mwh  residentialpv_techpot_quint  \
# 0                                   3.585222e+07                          4.0
# 1                                   1.257822e+08                          5.0
# 2                                   6.614827e+07                          3.0
# 3                                   1.926909e+07                          2.0
# 4                                   2.261702e+07                          4.0
#
#    residential_pv_technical_generation_potential_mwh  \
# 0                                          122752.69
# 1                                          483008.57
# 2                                           42823.79
# 3                                           37917.84
# 4                                          122024.81
#
#    landbasedwind_techpot_quint  \
# 0                            3
# 1                            3
# 2                            3
# 3                            3
# 4                            3
#
#    land_based_wind_technical_generation_potential_mwh  \
# 0                                         4374954.41
# 1                                         4368631.72
# 2                                         5898864.51
# 3                                         3986770.03
# 4                                         6117474.83
#
#    commercialpv_techpot_quint  \
# 0                         3.0
# 1                         5.0
# 2                         3.0
# 3                         3.0
# 4                         5.0
#
#    commercial_pv_technical_generation_potential_mwh  \
# 0                                          72863.02
# 1                                         361886.15
# 2                                          88221.80
# 3                                          64286.62
# 4                                         290436.00
#
#    commercialpv_lcoe_cap_quint  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#    commercial_pv_lcoe_capital_price_per_mw_median  commercialpv_lcoe_quint  \
# 0                                             NaN                      2.0
# 1                                             NaN                      2.0
# 2                                             NaN                      2.0
# 3                                             NaN                      3.0
# 4                                             NaN                      4.0
#
#    commercial_pv_lcoe_price_per_mwh_median  geothermal_lcoe_cap_quint  \
# 0                                66.302167                        NaN
# 1                                66.273569                        NaN
# 2                                66.894914                        NaN
# 3                                69.778835                        NaN
# 4                                71.363423                        NaN
#
#    geothermal_lcoe_capital_price_per_mw_median  geothermal_lcoe_quint  \
# 0                                          NaN                    NaN
# 1                                          NaN                    NaN
# 2                                          NaN                    NaN
# 3                                          NaN                    NaN
# 4                                          NaN                    NaN
#
#    geothermal_lcoe_price_per_mwh_median  hydro_lcoe_cap_quint  \
# 0                                   NaN                   2.0
# 1                                   NaN                   2.0
# 2                                   NaN                   2.0
# 3                                   NaN                   3.0
# 4                                   NaN                   2.0
#
#    hydro_lcoe_capital_price_per_mw_median  hydro_lcoe_quint  \
# 0                               6532994.0               1.0
# 1                               6532994.0               1.0
# 2                               6532994.0               1.0
# 3                               6839779.0               3.0
# 4                               6532994.0               1.0
#
#    hydro_lcoe_price_per_mwh_median  landbasedwind_lcoe_cap_quint  \
# 0                             23.0                           1.0
# 1                             23.0                           1.0
# 2                             23.0                           1.0
# 3                             25.0                           1.0
# 4                             23.0                           1.0
#
#    land_based_wind_lcoe_capital_price_per_mw_median  landbasedwind_lcoe_quint  \
# 0                                         1530092.0                       5.0
# 1                                         1530092.0                       5.0
# 2                                         1530092.0                       5.0
# 3                                         1530092.0                       4.0
# 4                                         1530092.0                       5.0
#
#    land_based_wind_lcoe_price_per_mwh_median  utilitypv_lcoe_cap_quint  \
# 0                                       67.0                       1.0
# 1                                       67.0                       1.0
# 2                                       67.0                       1.0
# 3                                       60.0                       1.0
# 4                                       67.0                       1.0
#
#    pv_lcoe_capital_price_per_mw_median  utilitypv_lcoe_quint  \
# 0                            1085440.0                   3.0
# 1                            1085440.0                   3.0
# 2                            1085440.0                   3.0
# 3                            1085440.0                   1.0
# 4                            1085440.0                   3.0
#
#    pv_lcoe_price_per_mwh_median  residentialpv_lcoe_cap_quint  \
# 0                          51.0                           NaN
# 1                          51.0                           NaN
# 2                          51.0                           NaN
# 3                          48.0                           NaN
# 4                          51.0                           NaN
#
#    residential_pv_lcoe_capital_price_per_mw_median  residentialpv_lcoe_quint  \
# 0                                              NaN                       2.0
# 1                                              NaN                       1.0
# 2                                              NaN                       2.0
# 3                                              NaN                       3.0
# 4                                              NaN                       4.0
#
#    residential_pv_lcoe_price_per_mwh_median  bev_growth_quint  \
# 0                                103.667192               4.0
# 1                                100.163323               4.0
# 2                                106.489305               2.0
# 3                                108.647593               3.0
# 4                                112.836845               2.0
#
#    hev_growth_quint  phev_growth_quint  icev_growth_quint  bev_prop_change  \
# 0               2.0                2.0                4.0         0.036473
# 1               4.0                3.0                2.0         0.037387
# 2               3.0                2.0                4.0         0.019624
# 3               1.0                3.0                4.0         0.023810
# 4               2.0                1.0                4.0         0.018640
#
#    hev_prop_change  phev_prop_change  icev_prop_change  \
# 0         0.026496          0.005495         -0.068464
# 1         0.048687          0.007595         -0.093669
# 2         0.042876          0.006752         -0.069252
# 3         0.018359          0.009185         -0.051353
# 4         0.031682          0.003464         -0.053786
#
#    bev_2018_reference_vehicle_counts  bev_2050_reference_vehicle_counts  \
# 0                              151.0                             2170.0
# 1                              446.0                             7556.0
# 2                               40.0                              484.0
# 3                               28.0                              466.0
# 4                               72.0                             1158.0
#
#    hev_gasoline_2018_reference_vehicle_counts  \
# 0                                       619.0
# 1                                      2591.0
# 2                                       286.0
# 3                                       132.0
# 4                                       454.0
#
#    hev_gasoline_2050_reference_vehicle_counts  \
# 0                                      2151.0
# 1                                     12068.0
# 2                                      1270.0
# 3                                       473.0
# 4                                      2341.0
#
#    phev_2018_reference_vehicle_counts  phev_2050_reference_vehicle_counts  \
# 0                                37.0                               343.0
# 1                               189.0                              1644.0
# 2                                17.0                               170.0
# 3                                12.0                               181.0
# 4                                31.0                               235.0
#
#    icev_gasoline_2018_reference_vehicle_counts  \
# 0                                      47791.0
# 1                                     167169.0
# 2                                      20669.0
# 3                                      17660.0
# 4                                      50846.0
#
#    icev_gasoline_2050_reference_vehicle_counts  reopt_savings_quint  \
# 0                                      50162.0                    0
# 1                                     167611.0                    0
# 2                                      20559.0                    1
# 3                                      17241.0                    0
# 4                                      54048.0                    0
#
#    cost_savings_per_county  energyburden_indicator  energyburden_1_prop  \
# 0                 0.000000                0.045833             0.583333
# 1                 0.000000                0.000000             0.741935
# 2                33.019786                0.122222             0.000000
# 3                 0.000000                0.000000             0.000000
# 4                 0.000000                0.000000             0.000000
#
#    energyburden_2_prop  energyburden_3_prop  energyburden_4_prop  \
# 0             0.333333             0.083333                  0.0
# 1             0.258065             0.000000                  0.0
# 2             0.777778             0.222222                  0.0
# 3             1.000000             0.000000                  0.0
# 4             1.000000             0.000000                  0.0
#
#    unemployment_quint  unemprate2020  mining_quint  pctempmining  \
# 0                   1            4.9             3      0.354783
# 1                   2            5.6             3      0.257648
# 2                   3            7.0             1      0.000000
# 3                   3            6.6             5      1.895791
# 4                   1            4.1             4      0.634211
#
#    ruralurbancontinuumcode2013  type_2015_farming_no  type_2015_mining_no  \
# 0                            2                     0                    0
# 1                            3                     0                    0
# 2                            6                     0                    0
# 3                            1                     0                    0
# 4                            1                     0                    0
#
#    population_loss_2015_update  perpov_1980_0711  minority_indicator  \
# 0                            0                 0            0.000000
# 1                            0                 0            0.000000
# 2                            0                 1            0.408696
# 3                            0                 0            0.066667
# 4                            0                 0            0.000000
#
#    minority_pop_1_prop  minority_pop_2_prop  minority_pop_3_prop  \
# 0             0.000000             0.343750             0.468750
# 1             0.308511             0.361702             0.255319
# 2             0.000000             0.086957             0.173913
# 3             0.266667             0.400000             0.000000
# 4             0.314286             0.371429             0.257143
#
#    minority_pop_4_prop  minority_pop_5_prop  lowincome_indicator  \
# 0             0.187500             0.000000             0.081250
# 1             0.042553             0.031915             0.023404
# 2             0.608696             0.130435             0.608696
# 3             0.266667             0.066667             0.266667
# 4             0.057143             0.000000             0.085714
#
#    lowincome_pop_1_prop  lowincome_pop_2_prop  lowincome_pop_3_prop  \
# 0              0.031250              0.281250              0.281250
# 1              0.127660              0.329787              0.202128
# 2              0.000000              0.000000              0.130435
# 3              0.066667              0.133333              0.200000
# 4              0.057143              0.142857              0.342857
#
#    lowincome_pop_4_prop  lowincome_pop_5_prop  lessthanhs_indicator  \
# 0              0.281250              0.125000              0.081250
# 1              0.223404              0.117021              0.000000
# 2              0.391304              0.478261              1.010435
# 3              0.266667              0.333333              0.486667
# 4              0.285714              0.171429              0.625714
#
#    lessthanhs_pop_1_prop  lessthanhs_pop_2_prop  lessthanhs_pop_3_prop  \
# 0               0.031250               0.312500               0.281250
# 1               0.202128               0.265957               0.202128
# 2               0.000000               0.000000               0.086957
# 3               0.066667               0.200000               0.066667
# 4               0.000000               0.085714               0.171429
#
#    lessthanhs_pop_4_prop  lessthanhs_pop_5_prop  pm25_indicator  pm25_1_prop  \
# 0               0.281250               0.093750        0.643750          0.0
# 1               0.191489               0.138298        0.000000          0.0
# 2               0.260870               0.652174        0.669565          0.0
# 3               0.266667               0.400000        0.000000          0.0
# 4               0.285714               0.457143        0.257143          0.0
#
#    pm25_2_prop  pm25_3_prop  pm25_4_prop  pm25_5_prop  ozone_indicator  \
# 0     0.000000     0.000000     0.156250     0.843750              0.0
# 1     0.225806     0.731183     0.043011     0.000000              0.0
# 2     0.000000     0.000000     0.130435     0.869565              0.0
# 3     0.000000     0.000000     0.800000     0.200000              0.0
# 4     0.000000     0.000000     0.542857     0.457143              0.0
#
#    ozone_1_prop  ozone_2_prop  ozone_3_prop  ozone_4_prop  ozone_5_prop  \
# 0      1.000000      0.000000           0.0           0.0           0.0
# 1      0.860215      0.139785           0.0           0.0           0.0
# 2      1.000000      0.000000           0.0           0.0           0.0
# 3      1.000000      0.000000           0.0           0.0           0.0
# 4      0.000000      1.000000           0.0           0.0           0.0
#
#    leadpaint_indicator  leadpaint_1_prop  leadpaint_2_prop  leadpaint_3_prop  \
# 0                  0.0          0.375000          0.437500          0.187500
# 1                  0.0          0.436170          0.414894          0.148936
# 2                  0.0          0.086957          0.304348          0.565217
# 3                  0.0          0.066667          0.533333          0.333333
# 4                  0.0          0.114286          0.485714          0.371429
#
#    leadpaint_4_prop  leadpaint_5_prop  diesel_indicator  \
# 0          0.000000               0.0               0.0
# 1          0.000000               0.0               0.0
# 2          0.043478               0.0               0.0
# 3          0.066667               0.0               0.0
# 4          0.028571               0.0               0.0
#
#    dieselparticulate_1_prop  dieselparticulate_2_prop  \
# 0                  0.156250                  0.437500
# 1                  0.043011                  0.806452
# 2                  0.782609                  0.217391
# 3                  0.800000                  0.200000
# 4                  0.257143                  0.742857
#
#    dieselparticulate_3_prop  dieselparticulate_4_prop  \
# 0                  0.312500                  0.093750
# 1                  0.129032                  0.021505
# 2                  0.000000                  0.000000
# 3                  0.000000                  0.000000
# 4                  0.000000                  0.000000
#
#    dieselparticulate_5_prop  cancer_indicator  cancerriskairtoxics_1_prop  \
# 0                       0.0          0.800000                         0.0
# 1                       0.0          0.047312                         0.0
# 2                       0.0          0.800000                         0.0
# 3                       0.0          0.800000                         0.0
# 4                       0.0          0.457143                         0.0
#
#    cancerriskairtoxics_2_prop  cancerriskairtoxics_3_prop  \
# 0                    0.000000                    0.000000
# 1                    0.043011                    0.215054
# 2                    0.000000                    0.000000
# 3                    0.000000                    0.000000
# 4                    0.000000                    0.000000
#
#    cancerriskairtoxics_4_prop  cancerriskairtoxics_5_prop  \
# 0                    0.000000                    1.000000
# 1                    0.494624                    0.247312
# 2                    0.000000                    1.000000
# 3                    0.000000                    1.000000
# 4                    0.342857                    0.657143
#
#    respiratory_indicator  respiratoryhazardairtoxics_1_prop  \
# 0               0.800000                                0.0
# 1               0.144086                                0.0
# 2               0.800000                                0.0
# 3               0.800000                                0.0
# 4               0.571429                                0.0
#
#    respiratoryhazardairtoxics_2_prop  respiratoryhazardairtoxics_3_prop  \
# 0                           0.000000                           0.000000
# 1                           0.043011                           0.225806
# 2                           0.000000                           0.000000
# 3                           0.000000                           0.000000
# 4                           0.000000                           0.000000
#
#    respiratoryhazardairtoxics_4_prop  respiratoryhazardairtoxics_5_prop  \
# 0                           0.000000                           1.000000
# 1                           0.387097                           0.344086
# 2                           0.000000                           1.000000
# 3                           0.000000                           1.000000
# 4                           0.228571                           0.771429
#
#    traffic_indicator  trafficproxvol_1_prop  trafficproxvol_2_prop  \
# 0                0.0               0.333333               0.200000
# 1                0.0               0.314607               0.359551
# 2                0.0               0.214286               0.428571
# 3                0.0               0.666667               0.333333
# 4                0.0               0.645161               0.290323
#
#    trafficproxvol_3_prop  trafficproxvol_4_prop  trafficproxvol_5_prop  \
# 0               0.333333               0.133333               0.000000
# 1               0.247191               0.067416               0.011236
# 2               0.285714               0.071429               0.000000
# 3               0.000000               0.000000               0.000000
# 4               0.064516               0.000000               0.000000
#
#    wastewater_indicator  wastewaterdischarge_1_prop  \
# 0              0.072727                    0.272727
# 1              0.000000                    0.246575
# 2              0.000000                    0.157895
# 3              0.550000                    0.083333
# 4              0.000000                    0.275862
#
#    wastewaterdischarge_2_prop  wastewaterdischarge_3_prop  \
# 0                    0.181818                    0.272727
# 1                    0.301370                    0.301370
# 2                    0.052632                    0.263158
# 3                    0.166667                    0.000000
# 4                    0.551724                    0.103448
#
#    wastewaterdischarge_4_prop  wastewaterdischarge_5_prop  npl_indicator  \
# 0                    0.000000                    0.272727            0.0
# 1                    0.150685                    0.000000            0.0
# 2                    0.368421                    0.157895            0.0
# 3                    0.000000                    0.750000            0.0
# 4                    0.068966                    0.000000            0.0
#
#    nplprox_1_prop  nplprox_2_prop  nplprox_3_prop  nplprox_4_prop  \
# 0        0.031250        0.281250        0.375000        0.312500
# 1        0.244681        0.680851        0.074468        0.000000
# 2        0.913043        0.086957        0.000000        0.000000
# 3        0.933333        0.066667        0.000000        0.000000
# 4        0.057143        0.828571        0.085714        0.028571
#
#    nplprox_5_prop  rmp_indicator  rmpprox_1_prop  rmpprox_2_prop  \
# 0             0.0            0.0        0.812500        0.156250
# 1             0.0            0.0        0.787234        0.127660
# 2             0.0            0.0        0.391304        0.173913
# 3             0.0            0.0        1.000000        0.000000
# 4             0.0            0.0        0.857143        0.085714
#
#    rmpprox_3_prop  rmpprox_4_prop  rmpprox_5_prop  tsdf_indicator  \
# 0        0.031250        0.000000             0.0             0.0
# 1        0.031915        0.053191             0.0             0.0
# 2        0.304348        0.130435             0.0             0.0
# 3        0.000000        0.000000             0.0             0.0
# 4        0.057143        0.000000             0.0             0.0
#
#    tsdfprox_1_prop  tsdfprox_2_prop  tsdfprox_3_prop  tsdfprox_4_prop  \
# 0         0.343750         0.187500         0.281250         0.156250
# 1         0.521277         0.297872         0.159574         0.021277
# 2         1.000000         0.000000         0.000000         0.000000
# 3         0.333333         0.600000         0.066667         0.000000
# 4         0.714286         0.171429         0.114286         0.000000
#
#    tsdfprox_5_prop
# 0          0.03125
# 1          0.00000
# 2          0.00000
# 3          0.00000
# 4          0.00000

# %% [markdown]
# cost_savings_per_county, minority_indicator, lowincome_indicator, pm25_indicator, cancer_indicator (cancer air toxics), respiratory_indicator (respiratory hazards air toxics)

# %%
# Assign features
new_data = eeip_data[['utility_pv_technical_generation_potential_mwh',
                'residential_pv_technical_generation_potential_mwh','land_based_wind_technical_generation_potential_mwh','commercial_pv_technical_generation_potential_mwh',
                # 'cost_savings_per_county',
                # 'minority_indicator',
                # 'lowincome_indicator',
                'pm25_indicator',
                'cancer_indicator',
                'respiratory_indicator']]

# Drop NAs from target features
new_data = new_data.dropna()

# Standardize the features
scaler = StandardScaler()
new_scaled = scaler.fit_transform(new_data)
new_scaled = pd.DataFrame(new_scaled, columns=new_data.columns)

# Print shape of standardized data frame
new_scaled.shape
# Out:
# (3107, 7)

# %%
# Perform clustering analysis
cluster_new = linkage(new_scaled, method='ward')

# Plot dendrogram tree
dendrogram(cluster_new, no_labels=True, show_leaf_counts=False)
plt.show()

# %%
# Based on the number of colors on the tree
num_clusters = 4 

# Extract cluster assignment
clust_assign = fcluster(cluster_mod, criterion='maxclust', t=num_clusters)

# Append cluster assignment to data frame 
new_scaled['cluster'] = clust_assign

# Find mean value of energy potential features for each cluster
mean_new = new_scaled.groupby('cluster').mean()
mean_new
# Out:
#          utility_pv_technical_generation_potential_mwh  \
# cluster
# 1                                             2.831068
# 2                                            -0.184742
# 3                                            -0.076363
# 4                                            -0.661236
#
#          residential_pv_technical_generation_potential_mwh  \
# cluster
# 1                                                -0.193351
# 2                                                -0.121549
# 3                                                 3.631745
# 4                                                26.888227
#
#          land_based_wind_technical_generation_potential_mwh  \
# cluster
# 1                                                 3.004580
# 2                                                -0.185776
# 3                                                -0.382148
# 4                                                -0.527199
#
#          commercial_pv_technical_generation_potential_mwh  pm25_indicator  \
# cluster
# 1                                               -0.197860       -0.185734
# 2                                               -0.104943       -0.027680
# 3                                                3.046819        1.121174
# 4                                               37.606587        4.090569
#
#          cancer_indicator  respiratory_indicator
# cluster
# 1               -0.314421              -0.346005
# 2                0.012778               0.014035
# 3                0.213703               0.236040
# 4                2.006669               2.201759

# %%
# Plot dodged Bar Chart
mean_new.plot(kind="bar", figsize=(8, 5))

# plt.xlabel("Cluster")
plt.ylabel("MWH")
plt.title("Energy potential across clusters")
plt.legend(title="Energy Indicator")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# Which EJSCREEN variable(s) did you add to the analysis? Why did you choose these?  What is the question you are interested in? What did you learn from the analysis

# %% [markdown]
# ***Your answer here***
