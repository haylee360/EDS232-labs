# %% [markdown]
# ## Deep Learning Example and Challenge

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
# Out:
# 2025-03-11 16:54:28.647109: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-11 16:54:28.685264: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-11 16:54:28.685292: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-11 16:54:28.686387: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-11 16:54:28.692695: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-11 16:54:29.450885: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Set random seed
np.random.seed(808)

# Generate simulated linear data
n = 1000
b = 30
a = 5

x = np.random.uniform(-1, 1, n).reshape(-1, 1)
y = b + a * x + np.random.randn(n, 1)

# %%
# Convert to DataFrame for visualization
sim = pd.DataFrame({'x': x.flatten(), 'y': y.flatten()})

#Plot the data
sns.scatterplot(x=sim['x'], y=sim['y'])
sns.regplot(x=sim['x'], y=sim['y'], scatter=False, color='red')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
# Fit an OLS Regression Model
ols_model = LinearRegression()
ols_model.fit(x, y)

# Print OLS coefficients
print(f"OLS Coefficients: Intercept = {ols_model.intercept_[0]}, Slope = {ols_model.coef_[0][0]}")
print(f"OLS Standard Deviation (Residual Error): {np.sqrt(mean_squared_error(y, ols_model.predict(x)))}")
# Out:
# OLS Coefficients: Intercept = 29.982631103504605, Slope = 4.924209306182985
# OLS Standard Deviation (Residual Error): 0.9921601015504126

# %%
# Build a simple neural network
model = keras.Sequential([
    keras.layers.Dense(units=1, activation='linear',
                       input_shape=(1,))])

# Compile the model
model.compile(optimizer='sgd', loss='mse')

# Train the model
history = model.fit(x, y, # data
                    batch_size=16, # mini-batch size 
                    epochs=20, # n times through full training data
                    validation_split=0.2, verbose=0
                   )

# %%
# Plot training history
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.title("Neural Network Training History")
plt.show()

# %%
# Compare weights from NN and OLS
nn_weights = model.get_weights()
print(f"NN Weights: Intercept = {nn_weights[1][0]}, Slope = {nn_weights[0][0][0]}")
print(f"OLS Coeffs: Intercept = {ols_model.intercept_[0]}, Slope = {ols_model.coef_[0][0]}")
# Out:
# NN Weights: Intercept = 29.96824073791504, Slope = 4.864788055419922
# OLS Coeffs: Intercept = 29.982631103504605, Slope = 4.924209306182985

# %%
# Generate Sine Wave Data
np.random.seed(321)
x_sine = np.linspace(-1, 2 * np.pi, n).reshape(-1, 1)
e_sine = np.random.normal(0, 0.2, n).reshape(-1, 1)
y_sine = np.sin(x_sine) + e_sine

# Convert to DataFrame
df_sine = pd.DataFrame({'x': x_sine.flatten(), 'y': y_sine.flatten()})

# Plot Sine Data
sns.scatterplot(x=df_sine['x'], y=df_sine['y'])
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
# Generate predictions
df_sine['pred'] = model.predict(df_sine[['x']]).flatten()  # Convert predictions to a 1D array
# Out:
# 32/32 [==============================] - 0s 1ms/step

# %%
sns.scatterplot(x=df_sine['x'], y=df_sine['y'], label='Data Points')
plt.plot(df_sine['x'], np.sin(df_sine['x']), color='cornflowerblue', label='True function')
plt.plot(df_sine['x'], df_sine['pred'], linestyle='dashed', color='red', label='Model prediction')

# %%
# Convert to DataFrame for visualization
sim = pd.DataFrame({'x': x.flatten(), 'y': y.flatten()})

#Plot the data
sns.scatterplot(x=sim['x'], y=sim['y'])
sns.regplot(x=sim['x'], y=sim['y'], scatter=False, color='red')

# %%
# Build a simple neural network
model2 = keras.Sequential([
    keras.layers.Dense(units=1, activation='linear',
                       input_shape=(1,))])

# Compile the model
model2.compile(optimizer='sgd', loss='mse')

# Train the model
history = model2.fit(x, y, # data
                    batch_size=20, # mini-batch size 
                    epochs=20, # n times through full training data
                    validation_split=0.2, verbose=0
                   )

# %%
df_sine['pred'] = model2.predict(df_sine[['x']]).flatten()  # Convert predictions to a 1D array
# Out:
# 32/32 [==============================] - 0s 1ms/step

# %%
sns.scatterplot(x=df_sine['x'], y=df_sine['y'], label='Data Points')
plt.plot(df_sine['x'], np.sin(df_sine['x']), color='cornflowerblue', label='True function')
plt.plot(df_sine['x'], df_sine['pred'], linestyle='dashed', color='red', label='Model prediction')

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# Generate sine wave data
x = np.linspace(-2*np.pi, 2*np.pi, 1000)
y = np.sin(x)

# Build a deeper network
model2 = keras.Sequential([
    keras.layers.Dense(16, activation='tanh', input_shape=(1,)),
    keras.layers.Dense(16, activation='tanh'),
    keras.layers.Dense(1)  # Linear output layer
])

# Compile with Adam optimizer
model2.compile(optimizer='adam', loss='mse')

# Train
history = model2.fit(x, y, epochs=100, batch_size=32, verbose=1)

# Test
import matplotlib.pyplot as plt
y_pred = model2.predict(x)

plt.plot(x, y, label="True sin(x)")
plt.plot(x, y_pred, label="NN Prediction")
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 3ms/step - loss: 0.3792
# Epoch 2/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2745
# Epoch 3/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2016
# Epoch 4/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1524
# Epoch 5/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1240
# Epoch 6/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1093
# Epoch 7/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1042
# Epoch 8/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0995
# Epoch 9/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0979
# Epoch 10/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0970
# Epoch 11/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0951
# Epoch 12/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0930
# Epoch 13/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0912
# Epoch 14/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0898
# Epoch 15/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0905
# Epoch 16/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0884
# Epoch 17/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0871
# Epoch 18/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0872
# Epoch 19/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0853
# Epoch 20/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0851
# Epoch 21/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0829
# Epoch 22/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0823
# Epoch 23/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0811
# Epoch 24/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0814
# Epoch 25/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0800
# Epoch 26/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0786
# Epoch 27/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0788
# Epoch 28/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0779
# Epoch 29/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0776
# Epoch 30/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0758
# Epoch 31/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0767
# Epoch 32/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0755
# Epoch 33/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0735
# Epoch 34/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0730
# Epoch 35/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0719
# Epoch 36/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0712
# Epoch 37/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0698
# Epoch 38/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0702
# Epoch 39/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0699
# Epoch 40/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0688
# Epoch 41/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0705
# Epoch 42/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0675
# Epoch 43/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0667
# Epoch 44/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0667
# Epoch 45/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0665
# Epoch 46/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0677
# Epoch 47/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0667
# Epoch 48/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0654
# Epoch 49/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0647
# Epoch 50/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0648
# Epoch 51/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0634
# Epoch 52/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0631
# Epoch 53/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0654
# Epoch 54/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0621
# Epoch 55/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0616
# Epoch 56/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0624
# Epoch 57/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0614
# Epoch 58/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0608
# Epoch 59/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0614
# Epoch 60/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0591
# Epoch 61/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0595
# Epoch 62/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0595
# Epoch 63/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0584
# Epoch 64/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0601
# Epoch 65/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0582
# Epoch 66/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0574
# Epoch 67/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0578
# Epoch 68/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0585
# Epoch 69/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0586
# Epoch 70/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0578
# Epoch 71/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0550
# Epoch 72/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0548
# Epoch 73/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0534
# Epoch 74/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0581
# Epoch 75/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0561
# Epoch 76/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0531
# Epoch 77/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0535
# Epoch 78/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0550
# Epoch 79/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0527
# Epoch 80/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0520
# Epoch 81/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0523
# Epoch 82/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0538
# Epoch 83/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0507
# Epoch 84/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0505
# Epoch 85/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0497
# Epoch 86/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0512
# Epoch 87/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0498
# Epoch 88/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0488
# Epoch 89/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0504
# Epoch 90/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0495
# Epoch 91/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0515
# Epoch 92/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0488
# Epoch 93/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0546
# Epoch 94/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0479
# Epoch 95/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0467
# Epoch 96/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0471
# Epoch 97/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0462
# Epoch 98/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0459
# Epoch 99/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0447
# Epoch 100/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0462
# 32/32 [==============================] - 0s 1ms/step
